# %% [markdown]
# Name: 			           Atharva Pravin Navghane
#
# Registration Number: 	 21BCE0083
#
# Email ID: 			       atharvapravin.n2021@vitstudent.ac.in
#
# Campus: 			         VIT Vellore
#
# Branch: 			         Computer Science and Engineering
#
# Phone Number: 		     9168975284

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# Task - 1 : Download the DataSet : House Price India.csv
# ---> Task 1 Done. Downloaded the File

# %%
# Task 2 : Load the Data Set
df = pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# Task 3: Perform the Below Visualisations

# %%
# a) Univariate Analysis

# --------------> Univariate Analysis of Price <----------------------
df.Price.plot()
# Out:
# <Axes: >

# %%
df.Price.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# -------------> Univariate Analysis of Number of Bedrooms <-------------------
df['number of bedrooms'].plot()
# Out:
# <Axes: >

# %%
df['number of bedrooms'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# -------------> Univariate Analysis of Number of Bathrooms <-------------------
df['number of bathrooms'].plot()
# Out:
# <Axes: >

# %%
df['number of bathrooms'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# --> Univariate Analysis of Number of Area of the house(excluding basement) <--
df['Area of the house(excluding basement)'].plot()
# Out:
# <Axes: >

# %%
df['Area of the house(excluding basement)'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# b) Bi-Variate Analysis

# --> Bivariate Analysis of Price and Number of Bedrooms <-----
sns.jointplot(data=df, x='number of bedrooms', y='Price')

# %%
sns.boxplot(data=df, x='number of bedrooms', y='Price')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
# --> Bivariate Analysis of Price and Number of Bathrooms <-----
sns.jointplot(data=df, x='number of bathrooms', y='Price')

# %%
sns.boxplot(data=df, x='number of bathrooms', y='Price')
# Out:
# <Axes: xlabel='number of bathrooms', ylabel='Price'>

# %%
# c) Multi-Variate Analysis

sns.pairplot(df[['living area', 'number of bedrooms', 'Price']])

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# Task 4: Perform descriptive statistics on the dataset.
#
# ---

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# Task 5: Handle the missing values

# %%
#We handle the missing values by inserting the mean value of the respective columns in that missing vlaues

#Step 1: Identify which columns have missing values and how many in each column:
print(df.isnull().sum())
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# As we can see above , none of the columns have any Missing Values and all the columns have been filled with some NON-NULL values.
# Hence there is no need to handle missing values as there are none.

# %% [markdown]
# # **THANK YOU** 🙂
